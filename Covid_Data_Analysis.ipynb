# %%
# !dir
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 0E8B-D1A4
#
#  Directory of C:\Users\dell
#
# 10/10/2024  11:16 PM    <DIR>          .
# 07/04/2023  10:07 PM    <DIR>          ..
# 06/28/2024  03:26 PM    <DIR>          .anaconda
# 01/03/2024  10:36 AM    <DIR>          .android
# 02/14/2024  10:23 AM               142 .angular-config.json
# 07/15/2023  01:11 AM               165 .bash_history
# 09/27/2024  09:59 AM    <DIR>          .cache
# 07/26/2024  03:36 PM    <DIR>          .conda
# 07/21/2023  01:21 AM                25 .condarc
# 07/21/2023  01:21 AM    <DIR>          .continuum
# 04/12/2024  09:59 AM             5,132 .dbshell
# 10/02/2024  11:27 PM    <DIR>          .dotnet
# 11/24/2022  08:15 PM    <DIR>          .eclipse
# 02/15/2024  09:23 PM                53 .git-for-windows-updater
# 07/13/2024  02:39 PM                85 .gitconfig
# 01/03/2024  01:01 PM    <DIR>          .gradle
# 01/06/2023  11:25 AM    <DIR>          .idlerc
# 10/10/2024  10:33 PM    <DIR>          .ipynb_checkpoints
# 07/21/2023  01:27 AM    <DIR>          .ipython
# 06/28/2024  03:32 PM    <DIR>          .jupyter
# 07/13/2024  02:32 PM                20 .lesshst
# 10/04/2023  03:06 PM    <DIR>          .m2
# 07/24/2023  10:53 PM    <DIR>          .matplotlib
# 01/01/2024  03:18 PM                 0 .mongorc.js
# 08/03/2023  10:41 PM    <DIR>          .ms-ad
# 01/17/2024  10:08 AM                 0 .node_repl_history
# 10/16/2023  03:14 PM    <DIR>          .p2
# 03/15/2023  10:05 AM               174 .packettracer
# 12/08/2023  03:18 PM    <DIR>          .swt
# 01/03/2024  10:48 AM    <DIR>          .vscode
# 04/10/2024  06:14 AM    <DIR>          .zenmap
# 08/17/2022  08:54 PM    <DIR>          3D Objects
# 12/20/2023  01:12 PM    <DIR>          aaqib
# 10/06/2024  11:36 PM         1,160,958 Advanced_Regression.ipynb
# 06/28/2024  03:25 PM    <DIR>          anaconda3
# 01/03/2024  10:17 AM    <DIR>          AndroidStudioProjects
# 02/14/2024  10:40 AM    <DIR>          angular17
# 11/15/2022  03:33 PM    <DIR>          Cisco Packet Tracer 7.3.0
# 07/05/2023  03:46 PM    <DIR>          Contacts
# 10/10/2024  11:16 PM           616,201 Covid.ipynb
# 10/08/2024  10:09 AM    <DIR>          Desktop
# 10/03/2024  10:10 AM    <DIR>          Documents
# 10/10/2024  12:00 AM    <DIR>          Downloads
# 09/06/2023  04:06 PM    <DIR>          eclipse
# 10/16/2023  03:15 PM    <DIR>          eclipse-workspace
# 07/29/2024  12:32 PM             2,604 Eye_recognition.ipynb
# 07/05/2023  03:46 PM    <DIR>          Favorites
# 10/04/2024  11:27 AM           115,438 Fraud_detection.ipynb
# 08/12/2024  02:47 PM    <DIR>          gensim-data
# 09/06/2023  10:35 PM                 0 internship
# 09/06/2023  09:42 PM                 0 landingpage
# 07/05/2023  03:46 PM    <DIR>          Links
# 07/24/2023  11:57 PM    <DIR>          Ml_be_prNumpy practical
# 07/05/2023  03:46 PM    <DIR>          Music
# 12/21/2022  09:48 AM    <DIR>          OneDrive
# 10/06/2024  11:36 PM            23,074 output.csv
# 12/19/2023  11:31 AM    <DIR>          Pictures
# 09/27/2024  11:57 AM            59,086 RAG MODEL.ipynb
# 07/05/2023  03:46 PM    <DIR>          Saved Games
# 09/29/2024  12:59 PM    <DIR>          Searches
# 07/21/2023  01:27 AM                72 Untitled.ipynb
# 10/17/2023  09:43 AM               589 Untitled1.ipynb
# 12/20/2023  01:34 PM               798 Untitled2.ipynb
# 06/26/2024  03:32 PM               589 Untitled3.ipynb
# 07/26/2024  03:30 PM             3,155 Untitled4.ipynb
# 08/11/2024  02:54 PM            31,021 Untitled5.ipynb
# 08/12/2024  11:55 AM                72 Untitled6.ipynb
# 08/12/2024  02:48 PM            80,982 Untitled7.ipynb
# 10/05/2024  07:42 PM             1,164 Untitled8.ipynb
# 07/05/2023  03:46 PM    <DIR>          Videos
# 07/29/2024  12:33 PM             2,866 Video_face and Eye_recognition.ipynb
#               28 File(s)      2,104,465 bytes
#               43 Dir(s)  338,582,253,568 bytes free

# %%
pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in c:\users\dell\anaconda3\lib\site-packages (24.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip3 install leather
# Out:
# Requirement already satisfied: leather in c:\users\dell\anaconda3\lib\site-packages (0.4.0)

# %%
# !pip install covid
# Out:
# Requirement already satisfied: covid in c:\users\dell\anaconda3\lib\site-packages (3.0.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\dell\anaconda3\lib\site-packages (from covid) (4.12.2)
# Requirement already satisfied: bleach>=3 in c:\users\dell\anaconda3\lib\site-packages (from covid) (4.1.0)
# Requirement already satisfied: click in c:\users\dell\anaconda3\lib\site-packages (from covid) (8.1.7)
# Requirement already satisfied: importlib-metadata in c:\users\dell\anaconda3\lib\site-packages (from covid) (7.0.1)
# Requirement already satisfied: inflection in c:\users\dell\anaconda3\lib\site-packages (from covid) (0.5.1)
# Requirement already satisfied: jeepney>=0.4.2 in c:\users\dell\anaconda3\lib\site-packages (from covid) (0.8.0)
# Requirement already satisfied: pydantic in c:\users\dell\anaconda3\lib\site-packages (from covid) (2.9.2)
# Requirement already satisfied: requests in c:\users\dell\anaconda3\lib\site-packages (from covid) (2.31.0)
# Requirement already satisfied: typer in c:\users\dell\anaconda3\lib\site-packages (from covid) (0.12.5)
# Requirement already satisfied: typing-extensions in c:\users\dell\anaconda3\lib\site-packages (from covid) (4.9.0)
# Requirement already satisfied: packaging in c:\users\dell\anaconda3\lib\site-packages (from bleach>=3->covid) (23.1)
# Requirement already satisfied: six>=1.9.0 in c:\users\dell\anaconda3\lib\site-packages (from bleach>=3->covid) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\dell\anaconda3\lib\site-packages (from bleach>=3->covid) (0.5.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\dell\anaconda3\lib\site-packages (from beautifulsoup4->covid) (2.5)
# Requirement already satisfied: colorama in c:\users\dell\anaconda3\lib\site-packages (from click->covid) (0.4.6)
# Requirement already satisfied: zipp>=0.5 in c:\users\dell\anaconda3\lib\site-packages (from importlib-metadata->covid) (3.17.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\dell\anaconda3\lib\site-packages (from pydantic->covid) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\dell\anaconda3\lib\site-packages (from pydantic->covid) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\dell\anaconda3\lib\site-packages (from requests->covid) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dell\anaconda3\lib\site-packages (from requests->covid) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dell\anaconda3\lib\site-packages (from requests->covid) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dell\anaconda3\lib\site-packages (from requests->covid) (2024.2.2)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\dell\anaconda3\lib\site-packages (from typer->covid) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\dell\anaconda3\lib\site-packages (from typer->covid) (13.3.5)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\dell\anaconda3\lib\site-packages (from rich>=10.11.0->typer->covid) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\dell\anaconda3\lib\site-packages (from rich>=10.11.0->typer->covid) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\dell\anaconda3\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich>=10.11.0->typer->covid) (0.1.0)

# %%
from covid import Covid

# %%
covid = Covid()

# %%
covid = Covid(source = "john_hopkins")

# %%
covid = Covid(source = "worldometers")

# %%
covid.get_data()
# Out:
# [{'country': 'North America',
#   'total_cases': 131889132,
#   'confirmed': 131889132,
#   'new_cases': 0,
#   'deaths': 1695941,
#   'new_deaths': 0,
#   'recovered': 127665129,
#   'active': 2528062,
#   'active_cases': 2528062,
#   'critical': 6095,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('0'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('0')},
#  {'country': 'Asia',
#   'total_cases': 221500265,
#   'confirmed': 221500265,
#   'new_cases': 0,
#   'deaths': 1553662,
#   'new_deaths': 0,
#   'recovered': 205673091,
#   'active': 14273512,
#   'active_cases': 14273512,
#   'critical': 14733,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('0'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('0')},
#  {'country': 'Europe',
#   'total_cases': 253406198,
#   'confirmed': 253406198,
#   'new_cases': 0,
#   'deaths': 2101824,
#   'new_deaths': 0,
#   'recovered': 248754104,
#   'active': 2550270,
#   'active_cases': 2550270,
#   'critical': 4453,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('0'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('0')},
#  {'country': 'South America',
#   'total_cases': 70200879,
#   'confirmed': 70200879,
#   'new_cases': 0,
#   'deaths': 1367332,
#   'new_deaths': 0,
#   'recovered': 66683585,
#   'active': 2149962,
#   'active_cases': 2149962,
#   'critical': 8953,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('0'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('0')},
#  {'country': 'Oceania',
#   'total_cases': 14895771,
#   'confirmed': 14895771,
#   'new_cases': 0,
#   'deaths': 33015,
#   'new_deaths': 0,
#   'recovered': 14752388,
#   'active': 110368,
#   'active_cases': 110368,
#   'critical': 31,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('0'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('0')},
#  {'country': 'Africa',
#   'total_cases': 12860924,
#   'confirmed': 12860924,
#   'new_cases': 0,
#   'deaths': 258892,
#   'new_deaths': 0,
#   'recovered': 12090808,
#   'active': 511224,
#   'active_cases': 511224,
#   'critical': 529,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('0'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('0')},
#  {'country': '0',
#   'total_cases': 721,
#   'confirmed': 721,
#   'new_cases': 0,
#   'deaths': 15,
#   'new_deaths': 0,
#   'recovered': 706,
#   'active': 0,
#   'active_cases': 0,
#   'critical': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('0'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('0')},
#  {'country': 'World',
#   'total_cases': 704753890,
#   'confirmed': 704753890,
#   'new_cases': 0,
#   'deaths': 7010681,
#   'new_deaths': 0,
#   'recovered': 675619811,
#   'active': 22123398,
#   'active_cases': 22123398,
#   'critical': 34794,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('90413'),
#   'total_deaths_per_million': Decimal('899.4'),
#   'population': Decimal('0')},
#  {'country': 'USA',
#   'total_cases': 111820082,
#   'confirmed': 111820082,
#   'new_cases': 0,
#   'deaths': 1219487,
#   'new_deaths': 0,
#   'recovered': 109814428,
#   'active': 786167,
#   'active_cases': 786167,
#   'critical': 940,
#   'total_tests': 1186851502,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('333985'),
#   'total_deaths_per_million': Decimal('3642'),
#   'population': Decimal('334805269')},
#  {'country': 'India',
#   'total_cases': 45035393,
#   'confirmed': 45035393,
#   'new_cases': 0,
#   'deaths': 533570,
#   'new_deaths': 0,
#   'recovered': 0,
#   'active': 0,
#   'active_cases': 0,
#   'critical': 0,
#   'total_tests': 935879495,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('32016'),
#   'total_deaths_per_million': Decimal('379'),
#   'population': Decimal('1406631776')},
#  {'country': 'France',
#   'total_cases': 40138560,
#   'confirmed': 40138560,
#   'new_cases': 0,
#   'deaths': 167642,
#   'new_deaths': 0,
#   'recovered': 39970918,
#   'active': 0,
#   'active_cases': 0,
#   'critical': 0,
#   'total_tests': 271490188,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('612013'),
#   'total_deaths_per_million': Decimal('2556'),
#   'population': Decimal('65584518')},
#  {'country': 'Germany',
#   'total_cases': 38828995,
#   'confirmed': 38828995,
#   'new_cases': 0,
#   'deaths': 183027,
#   'new_deaths': 0,
#   'recovered': 38240600,
#   'active': 405368,
#   'active_cases': 405368,
#   'critical': 0,
#   'total_tests': 122332384,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('462891'),
#   'total_deaths_per_million': Decimal('2182'),
#   'population': Decimal('83883596')},
#  {'country': 'Brazil',
#   'total_cases': 38743918,
#   'confirmed': 38743918,
#   'new_cases': 0,
#   'deaths': 711380,
#   'new_deaths': 0,
#   'recovered': 36249161,
#   'active': 1783377,
#   'active_cases': 1783377,
#   'critical': 0,
#   'total_tests': 63776166,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('179908'),
#   'total_deaths_per_million': Decimal('3303'),
#   'population': Decimal('215353593')},
#  {'country': 'S. Korea',
#   'total_cases': 34571873,
#   'confirmed': 34571873,
#   'new_cases': 0,
#   'deaths': 35934,
#   'new_deaths': 0,
#   'recovered': 34535939,
#   'active': 0,
#   'active_cases': 0,
#   'critical': 0,
#   'total_tests': 15804065,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('673523'),
#   'total_deaths_per_million': Decimal('700'),
#   'population': Decimal('51329899')},
#  {'country': 'Japan',
#   'total_cases': 33803572,
#   'confirmed': 33803572,
#   'new_cases': 0,
#   'deaths': 74694,
#   'new_deaths': 0,
#   'recovered': 0,
#   'active': 0,
#   'active_cases': 0,
#   'critical': 0,
#   'total_tests': 100414883,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('269169'),
#   'total_deaths_per_million': Decimal('595'),
#   'population': Decimal('125584838')},
#  {'country': 'Italy',
#   'total_cases': 26723249,
#   'confirmed': 26723249,
#   'new_cases': 0,
#   'deaths': 196487,
#   'new_deaths': 0,
#   'recovered': 26361218,
#   'active': 165544,
#   'active_cases': 165544,
#   'critical': 22,
#   'total_tests': 281126449,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('443445'),
#   'total_deaths_per_million': Decimal('3261'),
#   'population': Decimal('60262770')},
#  {'country': 'UK',
#   'total_cases': 24910387,
#   'confirmed': 24910387,
#   'new_cases': 0,
#   'deaths': 232112,
#   'new_deaths': 0,
#   'recovered': 24678275,
#   'active': 0,
#   'active_cases': 0,
#   'critical': 0,
#   'total_tests': 522526476,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('363666'),
#   'total_deaths_per_million': Decimal('3389'),
#   'population': Decimal('68497907')},
#  {'country': 'Russia',
#   'total_cases': 24124215,
#   'confirmed': 24124215,
#   'new_cases': 0,
#   'deaths': 402756,
#   'new_deaths': 0,
#   'recovered': 23545818,
#   'active': 175641,
#   'active_cases': 175641,
#   'critical': 0,
#   'total_tests': 273400000,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('165454'),
#   'total_deaths_per_million': Decimal('2762'),
#   'population': Decimal('145805947')},
#  {'country': 'Turkey',
#   'total_cases': 17232066,
#   'confirmed': 17232066,
#   'new_cases': 0,
#   'deaths': 102174,
#   'new_deaths': 0,
#   'recovered': 0,
#   'active': 0,
#   'active_cases': 0,
#   'critical': 0,
#   'total_tests': 162743369,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('201399'),
#   'total_deaths_per_million': Decimal('1194'),
#   'population': Decimal('85561976')},
#  {'country': 'Spain',
#   'total_cases': 13914811,
#   'confirmed': 13914811,
#   'new_cases': 0,
#   'deaths': 121760,
#   'new_deaths': 0,
#   'recovered': 13762417,
#   'active': 30634,
#   'active_cases': 30634,
#   'critical': 231,
#   'total_tests': 471036328,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('297840'),
#   'total_deaths_per_million': Decimal('2606'),
#   'population': Decimal('46719142')},
#  {'country': 'Australia',
#   'total_cases': 11853144,
#   'confirmed': 11853144,
#   'new_cases': 0,
#   'deaths': 24414,
#   'new_deaths': 0,
#   'recovered': 11820014,
#   'active': 8716,
#   'active_cases': 8716,
#   'critical': 3,
#   'total_tests': 81916639,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('454687'),
#   'total_deaths_per_million': Decimal('937'),
#   'population': Decimal('26068792')},
#  {'country': 'Vietnam',
#   'total_cases': 11625195,
#   'confirmed': 11625195,
#   'new_cases': 0,
#   'deaths': 43206,
#   'new_deaths': 0,
#   'recovered': 10640971,
#   'active': 941018,
#   'active_cases': 941018,
#   'critical': 0,
#   'total_tests': 85826548,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('117481'),
#   'total_deaths_per_million': Decimal('437'),
#   'population': Decimal('98953541')},
#  {'country': 'Taiwan',
#   'total_cases': 10241523,
#   'confirmed': 10241523,
#   'new_cases': 0,
#   'deaths': 19005,
#   'new_deaths': 0,
#   'recovered': 10222518,
#   'active': 0,
#   'active_cases': 0,
#   'critical': 0,
#   'total_tests': 30742304,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('428720'),
#   'total_deaths_per_million': Decimal('796'),
#   'population': Decimal('23888595')},
#  {'country': 'Argentina',
#   'total_cases': 10128845,
#   'confirmed': 10128845,
#   'new_cases': 0,
#   'deaths': 130841,
#   'new_deaths': 0,
#   'recovered': 9997258,
#   'active': 746,
#   'active_cases': 746,
#   'critical': 0,
#   'total_tests': 35716069,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('220143'),
#   'total_deaths_per_million': Decimal('2844'),
#   'population': Decimal('46010234')},
#  {'country': 'Netherlands',
#   'total_cases': 8635786,
#   'confirmed': 8635786,
#   'new_cases': 0,
#   'deaths': 22992,
#   'new_deaths': 0,
#   'recovered': 8612599,
#   'active': 195,
#   'active_cases': 195,
#   'critical': 0,
#   'total_tests': 25984435,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('501747'),
#   'total_deaths_per_million': Decimal('1336'),
#   'population': Decimal('17211447')},
#  {'country': 'Mexico',
#   'total_cases': 7702809,
#   'confirmed': 7702809,
#   'new_cases': 0,
#   'deaths': 334958,
#   'new_deaths': 0,
#   'recovered': 6899865,
#   'active': 467986,
#   'active_cases': 467986,
#   'critical': 0,
#   'total_tests': 20013810,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('58549'),
#   'total_deaths_per_million': Decimal('2546'),
#   'population': Decimal('131562772')},
#  {'country': 'Iran',
#   'total_cases': 7627186,
#   'confirmed': 7627186,
#   'new_cases': 0,
#   'deaths': 146811,
#   'new_deaths': 0,
#   'recovered': 0,
#   'active': 0,
#   'active_cases': 0,
#   'critical': 0,
#   'total_tests': 57320267,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('88665'),
#   'total_deaths_per_million': Decimal('1707'),
#   'population': Decimal('86022837')},
#  {'country': 'Indonesia',
#   'total_cases': 6829221,
#   'confirmed': 6829221,
#   'new_cases': 0,
#   'deaths': 162063,
#   'new_deaths': 0,
#   'recovered': 6647104,
#   'active': 20054,
#   'active_cases': 20054,
#   'critical': 0,
#   'total_tests': 114158919,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('24466'),
#   'total_deaths_per_million': Decimal('581'),
#   'population': Decimal('279134505')},
#  {'country': 'Poland',
#   'total_cases': 6661991,
#   'confirmed': 6661991,
#   'new_cases': 0,
#   'deaths': 120598,
#   'new_deaths': 0,
#   'recovered': 0,
#   'active': 0,
#   'active_cases': 0,
#   'critical': 0,
#   'total_tests': 39323709,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('176524'),
#   'total_deaths_per_million': Decimal('3196'),
#   'population': Decimal('37739785')},
#  {'country': 'Colombia',
#   'total_cases': 6400173,
#   'confirmed': 6400173,
#   'new_cases': 0,
#   'deaths': 143200,
#   'new_deaths': 0,
#   'recovered': 6212152,
#   'active': 44821,
#   'active_cases': 44821,
#   'critical': 342,
#   'total_tests': 36951507,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('124244'),
#   'total_deaths_per_million': Decimal('2780'),
#   'population': Decimal('51512762')},
#  {'country': 'Greece',
#   'total_cases': 6101379,
#   'confirmed': 6101379,
#   'new_cases': 0,
#   'deaths': 37869,
#   'new_deaths': 0,
#   'recovered': 0,
#   'active': 0,
#   'active_cases': 0,
#   'critical': 0,
#   'total_tests': 102228365,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('591412'),
#   'total_deaths_per_million': Decimal('3671'),
#   'population': Decimal('10316637')},
#  {'country': 'Austria',
#   'total_cases': 6081287,
#   'confirmed': 6081287,
#   'new_cases': 0,
#   'deaths': 22542,
#   'new_deaths': 0,
#   'recovered': 6054934,
#   'active': 3811,
#   'active_cases': 3811,
#   'critical': 0,
#   'total_tests': 211273524,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('670727'),
#   'total_deaths_per_million': Decimal('2486'),
#   'population': Decimal('9066710')},
#  {'country': 'Portugal',
#   'total_cases': 5643062,
#   'confirmed': 5643062,
#   'new_cases': 0,
#   'deaths': 28126,
#   'new_deaths': 0,
#   'recovered': 5614809,
#   'active': 127,
#   'active_cases': 127,
#   'critical': 61,
#   'total_tests': 46139518,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('556484'),
#   'total_deaths_per_million': Decimal('2774'),
#   'population': Decimal('10140570')},
#  {'country': 'Ukraine',
#   'total_cases': 5557995,
#   'confirmed': 5557995,
#   'new_cases': 0,
#   'deaths': 112418,
#   'new_deaths': 0,
#   'recovered': 5445577,
#   'active': 0,
#   'active_cases': 0,
#   'critical': 0,
#   'total_tests': 32603805,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('128681'),
#   'total_deaths_per_million': Decimal('2603'),
#   'population': Decimal('43192122')},
#  {'country': 'Chile',
#   'total_cases': 5384853,
#   'confirmed': 5384853,
#   'new_cases': 0,
#   'deaths': 64497,
#   'new_deaths': 0,
#   'recovered': 5252450,
#   'active': 67906,
#   'active_cases': 67906,
#   'critical': 7,
#   'total_tests': 50382097,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('279730'),
#   'total_deaths_per_million': Decimal('3350'),
#   'population': Decimal('19250195')},
#  {'country': 'Malaysia',
#   'total_cases': 5278406,
#   'confirmed': 5278406,
#   'new_cases': 0,
#   'deaths': 37348,
#   'new_deaths': 0,
#   'recovered': 5233268,
#   'active': 7790,
#   'active_cases': 7790,
#   'critical': 11,
#   'total_tests': 68580916,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('159079'),
#   'total_deaths_per_million': Decimal('1126'),
#   'population': Decimal('33181072')},
#  {'country': 'Canada',
#   'total_cases': 4946090,
#   'confirmed': 4946090,
#   'new_cases': 0,
#   'deaths': 59034,
#   'new_deaths': 0,
#   'recovered': 4881312,
#   'active': 5744,
#   'active_cases': 5744,
#   'critical': 99,
#   'total_tests': 66572774,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('128843'),
#   'total_deaths_per_million': Decimal('1538'),
#   'population': Decimal('38388419')},
#  {'country': 'Belgium',
#   'total_cases': 4861695,
#   'confirmed': 4861695,
#   'new_cases': 0,
#   'deaths': 34376,
#   'new_deaths': 0,
#   'recovered': 4826798,
#   'active': 521,
#   'active_cases': 521,
#   'critical': 0,
#   'total_tests': 37454182,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('416659'),
#   'total_deaths_per_million': Decimal('2946'),
#   'population': Decimal('11668278')},
#  {'country': 'Israel',
#   'total_cases': 4841772,
#   'confirmed': 4841772,
#   'new_cases': 0,
#   'deaths': 12707,
#   'new_deaths': 0,
#   'recovered': 4798473,
#   'active': 30592,
#   'active_cases': 30592,
#   'critical': 0,
#   'total_tests': 41373364,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('519169'),
#   'total_deaths_per_million': Decimal('1363'),
#   'population': Decimal('9326000')},
#  {'country': 'DPRK',
#   'total_cases': 4772813,
#   'confirmed': 4772813,
#   'new_cases': 0,
#   'deaths': 74,
#   'new_deaths': 0,
#   'recovered': 4772739,
#   'active': 0,
#   'active_cases': 0,
#   'critical': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('183636'),
#   'total_deaths_per_million': Decimal('3'),
#   'population': Decimal('25990679')},
#  {'country': 'Thailand',
#   'total_cases': 4770149,
#   'confirmed': 4770149,
#   'new_cases': 0,
#   'deaths': 34586,
#   'new_deaths': 0,
#   'recovered': 4692636,
#   'active': 42927,
#   'active_cases': 42927,
#   'critical': 0,
#   'total_tests': 17273454,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('68069'),
#   'total_deaths_per_million': Decimal('494'),
#   'population': Decimal('70078203')},
#  {'country': 'Czechia',
#   'total_cases': 4759041,
#   'confirmed': 4759041,
#   'new_cases': 0,
#   'deaths': 43517,
#   'new_deaths': 0,
#   'recovered': 4715206,
#   'active': 318,
#   'active_cases': 318,
#   'critical': 2,
#   'total_tests': 57834241,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('443246'),
#   'total_deaths_per_million': Decimal('4053'),
#   'population': Decimal('10736784')},
#  {'country': 'Peru',
#   'total_cases': 4572667,
#   'confirmed': 4572667,
#   'new_cases': 0,
#   'deaths': 222161,
#   'new_deaths': 0,
#   'recovered': 4350506,
#   'active': 0,
#   'active_cases': 0,
#   'critical': 4,
#   'total_tests': 39010194,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('135751'),
#   'total_deaths_per_million': Decimal('6595'),
#   'population': Decimal('33684208')},
#  {'country': 'Switzerland',
#   'total_cases': 4453053,
#   'confirmed': 4453053,
#   'new_cases': 0,
#   'deaths': 14452,
#   'new_deaths': 0,
#   'recovered': 4438309,
#   'active': 292,
#   'active_cases': 292,
#   'critical': 0,
#   'total_tests': 23833472,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('507549'),
#   'total_deaths_per_million': Decimal('1647'),
#   'population': Decimal('8773637')},
#  {'country': 'Philippines',
#   'total_cases': 4140383,
#   'confirmed': 4140383,
#   'new_cases': 0,
#   'deaths': 66864,
#   'new_deaths': 0,
#   'recovered': 4067381,
#   'active': 6138,
#   'active_cases': 6138,
#   'critical': 0,
#   'total_tests': 36102746,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('36800'),
#   'total_deaths_per_million': Decimal('594'),
#   'population': Decimal('112508994')},
#  {'country': 'South Africa',
#   'total_cases': 4076463,
#   'confirmed': 4076463,
#   'new_cases': 0,
#   'deaths': 102595,
#   'new_deaths': 0,
#   'recovered': 3912506,
#   'active': 61362,
#   'active_cases': 61362,
#   'critical': 192,
#   'total_tests': 26795090,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('67095'),
#   'total_deaths_per_million': Decimal('1689'),
#   'population': Decimal('60756135')},
#  {'country': 'Romania',
#   'total_cases': 3529735,
#   'confirmed': 3529735,
#   'new_cases': 0,
#   'deaths': 68929,
#   'new_deaths': 0,
#   'recovered': 3460149,
#   'active': 657,
#   'active_cases': 657,
#   'critical': 21,
#   'total_tests': 28758667,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('185470'),
#   'total_deaths_per_million': Decimal('3622'),
#   'population': Decimal('19031335')},
#  {'country': 'Denmark',
#   'total_cases': 3183756,
#   'confirmed': 3183756,
#   'new_cases': 0,
#   'deaths': 8814,
#   'new_deaths': 0,
#   'recovered': 3174942,
#   'active': 0,
#   'active_cases': 0,
#   'critical': 0,
#   'total_tests': 129333107,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('545636'),
#   'total_deaths_per_million': Decimal('1511'),
#   'population': Decimal('5834950')},
#  {'country': 'Singapore',
#   'total_cases': 3006155,
#   'confirmed': 3006155,
#   'new_cases': 0,
#   'deaths': 2024,
#   'new_deaths': 0,
#   'recovered': 3004131,
#   'active': 0,
#   'active_cases': 0,
#   'critical': 4,
#   'total_tests': 24756666,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('505785'),
#   'total_deaths_per_million': Decimal('341'),
#   'population': Decimal('5943546')},
#  {'country': 'Hong Kong',
#   'total_cases': 2937609,
#   'confirmed': 2937609,
#   'new_cases': 0,
#   'deaths': 14924,
#   'new_deaths': 0,
#   'recovered': 2916005,
#   'active': 6680,
#   'active_cases': 6680,
#   'critical': 0,
#   'total_tests': 76127725,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('386309'),
#   'total_deaths_per_million': Decimal('1963'),
#   'population': Decimal('7604299')},
#  {'country': 'Sweden',
#   'total_cases': 2754129,
#   'confirmed': 2754129,
#   'new_cases': 0,
#   'deaths': 27407,
#   'new_deaths': 0,
#   'recovered': 2726492,
#   'active': 230,
#   'active_cases': 230,
#   'critical': 0,
#   'total_tests': 19500873,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('269511'),
#   'total_deaths_per_million': Decimal('2682'),
#   'population': Decimal('10218971')},
#  {'country': 'New Zealand',
#   'total_cases': 2621111,
#   'confirmed': 2621111,
#   'new_cases': 0,
#   'deaths': 5697,
#   'new_deaths': 0,
#   'recovered': 2613791,
#   'active': 1623,
#   'active_cases': 1623,
#   'critical': 0,
#   'total_tests': 7768604,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('535117'),
#   'total_deaths_per_million': Decimal('1163'),
#   'population': Decimal('4898203')},
#  {'country': 'Serbia',
#   'total_cases': 2615054,
#   'confirmed': 2615054,
#   'new_cases': 0,
#   'deaths': 18057,
#   'new_deaths': 0,
#   'recovered': 2596608,
#   'active': 389,
#   'active_cases': 389,
#   'critical': 0,
#   'total_tests': 13463733,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('302213'),
#   'total_deaths_per_million': Decimal('2087'),
#   'population': Decimal('8653016')},
#  {'country': 'Iraq',
#   'total_cases': 2465545,
#   'confirmed': 2465545,
#   'new_cases': 0,
#   'deaths': 25375,
#   'new_deaths': 0,
#   'recovered': 2439497,
#   'active': 673,
#   'active_cases': 673,
#   'critical': 0,
#   'total_tests': 19544451,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('58474'),
#   'total_deaths_per_million': Decimal('602'),
#   'population': Decimal('42164965')},
#  {'country': 'Hungary',
#   'total_cases': 2230232,
#   'confirmed': 2230232,
#   'new_cases': 0,
#   'deaths': 49048,
#   'new_deaths': 0,
#   'recovered': 2152155,
#   'active': 29029,
#   'active_cases': 29029,
#   'critical': 0,
#   'total_tests': 11394556,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('232164'),
#   'total_deaths_per_million': Decimal('5106'),
#   'population': Decimal('9606259')},
#  {'country': 'Bangladesh',
#   'total_cases': 2049377,
#   'confirmed': 2049377,
#   'new_cases': 0,
#   'deaths': 29493,
#   'new_deaths': 0,
#   'recovered': 0,
#   'active': 0,
#   'active_cases': 0,
#   'critical': 0,
#   'total_tests': 15254399,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('12207'),
#   'total_deaths_per_million': Decimal('176'),
#   'population': Decimal('167885689')},
#  {'country': 'Slovakia',
#   'total_cases': 1877605,
#   'confirmed': 1877605,
#   'new_cases': 0,
#   'deaths': 21224,
#   'new_deaths': 0,
#   'recovered': 1856381,
#   'active': 0,
#   'active_cases': 0,
#   'critical': 23,
#   'total_tests': 7448789,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('343872'),
#   'total_deaths_per_million': Decimal('3887'),
#   'population': Decimal('5460193')},
#  {'country': 'Georgia',
#   'total_cases': 1861665,
#   'confirmed': 1861665,
#   'new_cases': 0,
#   'deaths': 17132,
#   'new_deaths': 0,
#   'recovered': 0,
#   'active': 0,
#   'active_cases': 0,
#   'critical': 0,
#   'total_tests': 16920079,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('469082'),
#   'total_deaths_per_million': Decimal('4317'),
#   'population': Decimal('3968738')},
#  {'country': 'Jordan',
#   'total_cases': 1746997,
#   'confirmed': 1746997,
#   'new_cases': 0,
#   'deaths': 14122,
#   'new_deaths': 0,
#   'recovered': 1731007,
#   'active': 1868,
#   'active_cases': 1868,
#   'critical': 59,
#   'total_tests': 17201885,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('169597'),
#   'total_deaths_per_million': Decimal('1371'),
#   'population': Decimal('10300869')},
#  {'country': 'Ireland',
#   'total_cases': 1734582,
#   'confirmed': 1734582,
#   'new_cases': 0,
#   'deaths': 9491,
#   'new_deaths': 0,
#   'recovered': 1724921,
#   'active': 170,
#   'active_cases': 170,
#   'critical': 19,
#   'total_tests': 13083449,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('345521'),
#   'total_deaths_per_million': Decimal('1891'),
#   'population': Decimal('5020199')},
#  {'country': 'Pakistan',
#   'total_cases': 1581936,
#   'confirmed': 1581936,
#   'new_cases': 0,
#   'deaths': 30664,
#   'new_deaths': 0,
#   'recovered': 1538689,
#   'active': 12583,
#   'active_cases': 12583,
#   'critical': 0,
#   'total_tests': 30589153,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('6893'),
#   'total_deaths_per_million': Decimal('134'),
#   'population': Decimal('229488994')},
#  {'country': 'Finland',
#   'total_cases': 1516117,
#   'confirmed': 1516117,
#   'new_cases': 0,
#   'deaths': 11958,
#   'new_deaths': 0,
#   'recovered': 1503989,
#   'active': 170,
#   'active_cases': 170,
#   'critical': 0,
#   'total_tests': 12108977,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('272930'),
#   'total_deaths_per_million': Decimal('2153'),
#   'population': Decimal('5554960')},
#  {'country': 'Norway',
#   'total_cases': 1509732,
#   'confirmed': 1509732,
#   'new_cases': 0,
#   'deaths': 6638,
#   'new_deaths': 0,
#   'recovered': 1503094,
#   'active': 0,
#   'active_cases': 0,
#   'critical': 0,
#   'total_tests': 11002430,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('273930'),
#   'total_deaths_per_million': Decimal('1204'),
#   'population': Decimal('5511370')},
#  {'country': 'Kazakhstan',
#   'total_cases': 1411831,
#   'confirmed': 1411831,
#   'new_cases': 0,
#   'deaths': 13848,
#   'new_deaths': 0,
#   'recovered': 1383020,
#   'active': 14963,
#   'active_cases': 14963,
#   'critical': 24,
#   'total_tests': 11575012,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('73514'),
#   'total_deaths_per_million': Decimal('721'),
#   'population': Decimal('19205043')},
#  {'country': 'Lithuania',
#   'total_cases': 1397806,
#   'confirmed': 1397806,
#   'new_cases': 0,
#   'deaths': 9897,
#   'new_deaths': 0,
#   'recovered': 1387478,
#   'active': 431,
#   'active_cases': 431,
#   'critical': 0,
#   'total_tests': 10540357,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('525154'),
#   'total_deaths_per_million': Decimal('3718'),
#   'population': Decimal('2661708')},
#  {'country': 'Slovenia',
#   'total_cases': 1356546,
#   'confirmed': 1356546,
#   'new_cases': 0,
#   'deaths': 7100,
#   'new_deaths': 0,
#   'recovered': 1349424,
#   'active': 22,
#   'active_cases': 22,
#   'critical': 0,
#   'total_tests': 2847701,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('652803'),
#   'total_deaths_per_million': Decimal('3417'),
#   'population': Decimal('2078034')},
#  {'country': 'Bulgaria',
#   'total_cases': 1339851,
#   'confirmed': 1339851,
#   'new_cases': 0,
#   'deaths': 38748,
#   'new_deaths': 0,
#   'recovered': 1292944,
#   'active': 8159,
#   'active_cases': 8159,
#   'critical': 22,
#   'total_tests': 11671043,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('195753'),
#   'total_deaths_per_million': Decimal('5661'),
#   'population': Decimal('6844597')},
#  {'country': 'Croatia',
#   'total_cases': 1309728,
#   'confirmed': 1309728,
#   'new_cases': 0,
#   'deaths': 18687,
#   'new_deaths': 0,
#   'recovered': 1258432,
#   'active': 32609,
#   'active_cases': 32609,
#   'critical': 0,
#   'total_tests': 5660084,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('322650'),
#   'total_deaths_per_million': Decimal('4604'),
#   'population': Decimal('4059286')},
#  {'country': 'Guatemala',
#   'total_cases': 1291293,
#   'confirmed': 1291293,
#   'new_cases': 0,
#   'deaths': 20289,
#   'new_deaths': 0,
#   'recovered': 1269891,
#   'active': 1113,
#   'active_cases': 1113,
#   'critical': 5,
#   'total_tests': 7593848,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('69484'),
#   'total_deaths_per_million': Decimal('1092'),
#   'population': Decimal('18584039')},
#  {'country': 'Morocco',
#   'total_cases': 1278992,
#   'confirmed': 1278992,
#   'new_cases': 0,
#   'deaths': 16303,
#   'new_deaths': 0,
#   'recovered': 0,
#   'active': 0,
#   'active_cases': 0,
#   'critical': 0,
#   'total_tests': 13001033,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('33860'),
#   'total_deaths_per_million': Decimal('432'),
#   'population': Decimal('37772756')},
#  {'country': 'Lebanon',
#   'total_cases': 1243838,
#   'confirmed': 1243838,
#   'new_cases': 0,
#   'deaths': 10952,
#   'new_deaths': 0,
#   'recovered': 1087587,
#   'active': 145299,
#   'active_cases': 145299,
#   'critical': 74,
#   'total_tests': 4795578,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('186068'),
#   'total_deaths_per_million': Decimal('1638'),
#   'population': Decimal('6684849')},
#  {'country': 'Costa Rica',
#   'total_cases': 1238883,
#   'confirmed': 1238883,
#   'new_cases': 0,
#   'deaths': 9428,
#   'new_deaths': 0,
#   'recovered': 0,
#   'active': 0,
#   'active_cases': 0,
#   'critical': 0,
#   'total_tests': 4659757,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('239058'),
#   'total_deaths_per_million': Decimal('1819'),
#   'population': Decimal('5182354')},
#  {'country': 'Bolivia',
#   'total_cases': 1212131,
#   'confirmed': 1212131,
#   'new_cases': 0,
#   'deaths': 22407,
#   'new_deaths': 0,
#   'recovered': 1177145,
#   'active': 12579,
#   'active_cases': 12579,
#   'critical': 220,
#   'total_tests': 2710261,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('101073'),
#   'total_deaths_per_million': Decimal('1868'),
#   'population': Decimal('11992656')},
#  {'country': 'Tunisia',
#   'total_cases': 1153361,
#   'confirmed': 1153361,
#   'new_cases': 0,
#   'deaths': 29423,
#   'new_deaths': 0,
#   'recovered': 0,
#   'active': 0,
#   'active_cases': 0,
#   'critical': 0,
#   'total_tests': 5013383,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('95741'),
#   'total_deaths_per_million': Decimal('2442'),
#   'population': Decimal('12046656')},
#  {'country': 'Cuba',
#   'total_cases': 1115251,
#   'confirmed': 1115251,
#   'new_cases': 0,
#   'deaths': 8530,
#   'new_deaths': 0,
#   'recovered': 1106660,
#   'active': 61,
#   'active_cases': 61,
#   'critical': 0,
#   'total_tests': 14402674,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('98645'),
#   'total_deaths_per_million': Decimal('754'),
#   'population': Decimal('11305652')},
#  {'country': 'Ecuador',
#   'total_cases': 1070188,
#   'confirmed': 1070188,
#   'new_cases': 0,
#   'deaths': 36043,
#   'new_deaths': 0,
#   'recovered': 1034145,
#   'active': 0,
#   'active_cases': 0,
#   'critical': 0,
#   'total_tests': 3082403,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('59083'),
#   'total_deaths_per_million': Decimal('1990'),
#   'population': Decimal('18113361')},
#  {'country': 'UAE',
#   'total_cases': 1067030,
#   'confirmed': 1067030,
#   'new_cases': 0,
#   'deaths': 2349,
#   'new_deaths': 0,
#   'recovered': 0,
#   'active': 0,
#   'active_cases': 0,
#   'critical': 0,
#   'total_tests': 200732262,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('105837'),
#   'total_deaths_per_million': Decimal('233'),
#   'population': Decimal('10081785')},
#  {'country': 'Panama',
#   'total_cases': 1059893,
#   'confirmed': 1059893,
#   'new_cases': 0,
#   'deaths': 8727,
#   'new_deaths': 0,
#   'recovered': 1051102,
#   'active': 64,
#   'active_cases': 64,
#   'critical': 16,
#   'total_tests': 7882622,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('238341'),
#   'total_deaths_per_million': Decimal('1962'),
#   'population': Decimal('4446964')},
#  {'country': 'Uruguay',
#   'total_cases': 1041111,
#   'confirmed': 1041111,
#   'new_cases': 0,
#   'deaths': 7664,
#   'new_deaths': 0,
#   'recovered': 1030944,
#   'active': 2503,
#   'active_cases': 2503,
#   'critical': 18,
#   'total_tests': 6114822,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('297799'),
#   'total_deaths_per_million': Decimal('2192'),
#   'population': Decimal('3496016')},
#  {'country': 'Mongolia',
#   'total_cases': 1011496,
#   'confirmed': 1011496,
#   'new_cases': 0,
#   'deaths': 2284,
#   'new_deaths': 0,
#   'recovered': 1009212,
#   'active': 0,
#   'active_cases': 0,
#   'critical': 0,
#   'total_tests': 4030048,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('299429'),
#   'total_deaths_per_million': Decimal('676'),
#   'population': Decimal('3378078')},
#  {'country': 'Nepal',
#   'total_cases': 1003450,
#   'confirmed': 1003450,
#   'new_cases': 0,
#   'deaths': 12031,
#   'new_deaths': 0,
#   'recovered': 991322,
#   'active': 97,
#   'active_cases': 97,
#   'critical': 0,
#   'total_tests': 6047766,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('33199'),
#   'total_deaths_per_million': Decimal('398'),
#   'population': Decimal('30225582')},
#  {'country': 'Belarus',
#   'total_cases': 994037,
#   'confirmed': 994037,
#   'new_cases': 0,
#   'deaths': 7118,
#   'new_deaths': 0,
#   'recovered': 985592,
#   'active': 1327,
#   'active_cases': 1327,
#   'critical': 0,
#   'total_tests': 13646641,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('105381'),
#   'total_deaths_per_million': Decimal('755'),
#   'population': Decimal('9432800')},
#  {'country': 'Latvia',
#   'total_cases': 982505,
#   'confirmed': 982505,
#   'new_cases': 0,
#   'deaths': 6715,
#   'new_deaths': 0,
#   'recovered': 971406,
#   'active': 4384,
#   'active_cases': 4384,
#   'critical': 0,
#   'total_tests': 7885792,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('531418'),
#   'total_deaths_per_million': Decimal('3632'),
#   'population': Decimal('1848837')},
#  {'country': 'Saudi Arabia',
#   'total_cases': 841469,
#   'confirmed': 841469,
#   'new_cases': 0,
#   'deaths': 9646,
#   'new_deaths': 0,
#   'recovered': 0,
#   'active': 0,
#   'active_cases': 0,
#   'critical': 0,
#   'total_tests': 45481735,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('23475'),
#   'total_deaths_per_million': Decimal('269'),
#   'population': Decimal('35844909')},
#  {'country': 'Paraguay',
#   'total_cases': 837602,
#   'confirmed': 837602,
#   'new_cases': 0,
#   'deaths': 20155,
#   'new_deaths': 0,
#   'recovered': 0,
#   'active': 0,
#   'active_cases': 0,
#   'critical': 0,
#   'total_tests': 2657506,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('114648'),
#   'total_deaths_per_million': Decimal('2759'),
#   'population': Decimal('7305843')},
#  {'country': 'Azerbaijan',
#   'total_cases': 835234,
#   'confirmed': 835234,
#   'new_cases': 0,
#   'deaths': 10400,
#   'new_deaths': 0,
#   'recovered': 824089,
#   'active': 745,
#   'active_cases': 745,
#   'critical': 0,
#   'total_tests': 7748050,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('81089'),
#   'total_deaths_per_million': Decimal('1010'),
#   'population': Decimal('10300205')},
#  {'country': 'Bahrain',
#   'total_cases': 729549,
#   'confirmed': 729549,
#   'new_cases': 0,
#   'deaths': 1574,
#   'new_deaths': 0,
#   'recovered': 727915,
#   'active': 60,
#   'active_cases': 60,
#   'critical': 0,
#   'total_tests': 10948549,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('408944'),
#   'total_deaths_per_million': Decimal('882'),
#   'population': Decimal('1783983')},
#  {'country': 'Cyprus',
#   'total_cases': 681110,
#   'confirmed': 681110,
#   'new_cases': 0,
#   'deaths': 1365,
#   'new_deaths': 0,
#   'recovered': 679745,
#   'active': 0,
#   'active_cases': 0,
#   'critical': 0,
#   'total_tests': 9640118,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('556741'),
#   'total_deaths_per_million': Decimal('1116'),
#   'population': Decimal('1223387')},
#  {'country': 'Dominican Republic',
#   'total_cases': 675890,
#   'confirmed': 675890,
#   'new_cases': 0,
#   'deaths': 4384,
#   'new_deaths': 0,
#   'recovered': 671316,
#   'active': 190,
#   'active_cases': 190,
#   'critical': 4,
#   'total_tests': 3740928,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('61131'),
#   'total_deaths_per_million': Decimal('397'),
#   'population': Decimal('11056370')},
#  {'country': 'Sri Lanka',
#   'total_cases': 672754,
#   'confirmed': 672754,
#   'new_cases': 0,
#   'deaths': 16897,
#   'new_deaths': 0,
#   'recovered': 655852,
#   'active': 5,
#   'active_cases': 5,
#   'critical': 0,
#   'total_tests': 6486117,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('31181'),
#   'total_deaths_per_million': Decimal('783'),
#   'population': Decimal('21575842')},
#  {'country': 'Kuwait',
#   'total_cases': 667158,
#   'confirmed': 667158,
#   'new_cases': 0,
#   'deaths': 2570,
#   'new_deaths': 0,
#   'recovered': 0,
#   'active': 0,
#   'active_cases': 0,
#   'critical': 0,
#   'total_tests': 8455743,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('152308'),
#   'total_deaths_per_million': Decimal('587'),
#   'population': Decimal('4380326')},
#  {'country': 'Myanmar',
#   'total_cases': 641873,
#   'confirmed': 641873,
#   'new_cases': 0,
#   'deaths': 19495,
#   'new_deaths': 0,
#   'recovered': 620159,
#   'active': 2219,
#   'active_cases': 2219,
#   'critical': 0,
#   'total_tests': 11711514,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('11622'),
#   'total_deaths_per_million': Decimal('353'),
#   'population': Decimal('55227143')},
#  {'country': 'Moldova',
#   'total_cases': 635145,
#   'confirmed': 635145,
#   'new_cases': 0,
#   'deaths': 12218,
#   'new_deaths': 0,
#   'recovered': 0,
#   'active': 0,
#   'active_cases': 0,
#   'critical': 0,
#   'total_tests': 3216305,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('158265'),
#   'total_deaths_per_million': Decimal('3044'),
#   'population': Decimal('4013171')},
#  {'country': 'Estonia',
#   'total_cases': 628070,
#   'confirmed': 628070,
#   'new_cases': 0,
#   'deaths': 3001,
#   'new_deaths': 0,
#   'recovered': 0,
#   'active': 0,
#   'active_cases': 0,
#   'critical': 0,
#   'total_tests': 6968103,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('475123'),
#   'total_deaths_per_million': Decimal('2270'),
#   'population': Decimal('1321910')},
#  {'country': 'Palestine',
#   'total_cases': 621008,
#   'confirmed': 621008,
#   'new_cases': 0,
#   'deaths': 5404,
#   'new_deaths': 0,
#   'recovered': 615445,
#   'active': 159,
#   'active_cases': 159,
#   'critical': 0,
#   'total_tests': 3078533,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('116173'),
#   'total_deaths_per_million': Decimal('1011'),
#   'population': Decimal('5345541')},
#  {'country': 'Venezuela',
#   'total_cases': 552695,
#   'confirmed': 552695,
#   'new_cases': 0,
#   'deaths': 5856,
#   'new_deaths': 0,
#   'recovered': 546537,
#   'active': 302,
#   'active_cases': 302,
#   'critical': 31,
#   'total_tests': 3359014,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('18885'),
#   'total_deaths_per_million': Decimal('200'),
#   'population': Decimal('29266991')},
#  {'country': 'Egypt',
#   'total_cases': 516023,
#   'confirmed': 516023,
#   'new_cases': 0,
#   'deaths': 24613,
#   'new_deaths': 0,
#   'recovered': 442182,
#   'active': 49228,
#   'active_cases': 49228,
#   'critical': 122,
#   'total_tests': 3693367,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('4861'),
#   'total_deaths_per_million': Decimal('232'),
#   'population': Decimal('106156692')},
#  {'country': 'Qatar',
#   'total_cases': 514524,
#   'confirmed': 514524,
#   'new_cases': 0,
#   'deaths': 690,
#   'new_deaths': 0,
#   'recovered': 513687,
#   'active': 147,
#   'active_cases': 147,
#   'critical': 16,
#   'total_tests': 4065369,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('172664'),
#   'total_deaths_per_million': Decimal('232'),
#   'population': Decimal('2979915')},
#  {'country': 'Libya',
#   'total_cases': 507274,
#   'confirmed': 507274,
#   'new_cases': 0,
#   'deaths': 6437,
#   'new_deaths': 0,
#   'recovered': 500835,
#   'active': 2,
#   'active_cases': 2,
#   'critical': 0,
#   'total_tests': 2483848,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('72048'),
#   'total_deaths_per_million': Decimal('914'),
#   'population': Decimal('7040745')},
#  {'country': 'Ethiopia',
#   'total_cases': 501157,
#   'confirmed': 501157,
#   'new_cases': 0,
#   'deaths': 7574,
#   'new_deaths': 0,
#   'recovered': 488171,
#   'active': 5412,
#   'active_cases': 5412,
#   'critical': 0,
#   'total_tests': 5565340,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('4148'),
#   'total_deaths_per_million': Decimal('63'),
#   'population': Decimal('120812698')},
#  {'country': 'Réunion',
#   'total_cases': 494595,
#   'confirmed': 494595,
#   'new_cases': 0,
#   'deaths': 921,
#   'new_deaths': 0,
#   'recovered': 0,
#   'active': 0,
#   'active_cases': 0,
#   'critical': 0,
#   'total_tests': 1603660,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('544672'),
#   'total_deaths_per_million': Decimal('1014'),
#   'population': Decimal('908061')},
#  {'country': 'Honduras',
#   'total_cases': 474590,
#   'confirmed': 474590,
#   'new_cases': 0,
#   'deaths': 11165,
#   'new_deaths': 0,
#   'recovered': 0,
#   'active': 0,
#   'active_cases': 0,
#   'critical': 0,
#   'total_tests': 1660662,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('46432'),
#   'total_deaths_per_million': Decimal('1092'),
#   'population': Decimal('10221247')},
#  {'country': 'Armenia',
#   'total_cases': 451831,
#   'confirmed': 451831,
#   'new_cases': 0,
#   'deaths': 8777,
#   'new_deaths': 0,
#   'recovered': 435162,
#   'active': 7892,
#   'active_cases': 7892,
#   'critical': 0,
#   'total_tests': 3242901,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('152031'),
#   'total_deaths_per_million': Decimal('2953'),
#   'population': Decimal('2971966')},
#  {'country': 'Bosnia and Herzegovina',
#   'total_cases': 403615,
#   'confirmed': 403615,
#   'new_cases': 0,
#   'deaths': 16388,
#   'new_deaths': 0,
#   'recovered': 379084,
#   'active': 8143,
#   'active_cases': 8143,
#   'critical': 0,
#   'total_tests': 1884721,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('124215'),
#   'total_deaths_per_million': Decimal('5044'),
#   'population': Decimal('3249317')},
#  {'country': 'Oman',
#   'total_cases': 399449,
#   'confirmed': 399449,
#   'new_cases': 0,
#   'deaths': 4628,
#   'new_deaths': 0,
#   'recovered': 0,
#   'active': 0,
#   'active_cases': 0,
#   'critical': 0,
#   'total_tests': 25000000,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('75028'),
#   'total_deaths_per_million': Decimal('869'),
#   'population': Decimal('5323993')},
#  {'country': 'Luxembourg',
#   'total_cases': 391232,
#   'confirmed': 391232,
#   'new_cases': 0,
#   'deaths': 1232,
#   'new_deaths': 0,
#   'recovered': 0,
#   'active': 0,
#   'active_cases': 0,
#   'critical': 0,
#   'total_tests': 4587145,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('609044'),
#   'total_deaths_per_million': Decimal('1918'),
#   'population': Decimal('642371')},
#  {'country': 'North Macedonia',
#   'total_cases': 350567,
#   'confirmed': 350567,
#   'new_cases': 0,
#   'deaths': 9976,
#   'new_deaths': 0,
#   'recovered': 337068,
#   'active': 3523,
#   'active_cases': 3523,
#   'critical': 0,
#   'total_tests': 2226216,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('168436'),
#   'total_deaths_per_million': Decimal('4793'),
#   'population': Decimal('2081304')},
#  {'country': 'Zambia',
#   'total_cases': 349304,
#   'confirmed': 349304,
#   'new_cases': 0,
#   'deaths': 4069,
#   'new_deaths': 0,
#   'recovered': 341316,
#   'active': 3919,
#   'active_cases': 3919,
#   'critical': 0,
#   'total_tests': 4112961,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('17940'),
#   'total_deaths_per_million': Decimal('209'),
#   'population': Decimal('19470234')},
#  {'country': 'Kenya',
#   'total_cases': 344130,
#   'confirmed': 344130,
#   'new_cases': 0,
#   'deaths': 5689,
#   'new_deaths': 0,
#   'recovered': 337309,
#   'active': 1132,
#   'active_cases': 1132,
#   'critical': 0,
#   'total_tests': 3967062,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('6122'),
#   'total_deaths_per_million': Decimal('101'),
#   'population': Decimal('56215221')},
#  {'country': 'Brunei',
#   'total_cases': 343719,
#   'confirmed': 343719,
#   'new_cases': 0,
#   'deaths': 225,
#   'new_deaths': 0,
#   'recovered': 243601,
#   'active': 99893,
#   'active_cases': 99893,
#   'critical': 3,
#   'total_tests': 717784,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('771655'),
#   'total_deaths_per_million': Decimal('505'),
#   'population': Decimal('445431')},
#  {'country': 'Albania',
#   'total_cases': 334863,
#   'confirmed': 334863,
#   'new_cases': 0,
#   'deaths': 3605,
#   'new_deaths': 0,
#   'recovered': 330233,
#   'active': 1025,
#   'active_cases': 1025,
#   'critical': 0,
#   'total_tests': 1941032,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('116825'),
#   'total_deaths_per_million': Decimal('1258'),
#   'population': Decimal('2866374')},
#  {'country': 'Botswana',
#   'total_cases': 330638,
#   'confirmed': 330638,
#   'new_cases': 0,
#   'deaths': 2801,
#   'new_deaths': 0,
#   'recovered': 327049,
#   'active': 788,
#   'active_cases': 788,
#   'critical': 1,
#   'total_tests': 2026898,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('135443'),
#   'total_deaths_per_million': Decimal('1147'),
#   'population': Decimal('2441162')},
#  {'country': 'Montenegro',
#   'total_cases': 296542,
#   'confirmed': 296542,
#   'new_cases': 0,
#   'deaths': 2846,
#   'new_deaths': 0,
#   'recovered': 291794,
#   'active': 1902,
#   'active_cases': 1902,
#   'critical': 0,
#   'total_tests': 2769281,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('472238'),
#   'total_deaths_per_million': Decimal('4532'),
#   'population': Decimal('627950')},
#  {'country': 'Algeria',
#   'total_cases': 272010,
#   'confirmed': 272010,
#   'new_cases': 0,
#   'deaths': 6881,
#   'new_deaths': 0,
#   'recovered': 183061,
#   'active': 82068,
#   'active_cases': 82068,
#   'critical': 0,
#   'total_tests': 230960,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('5998'),
#   'total_deaths_per_million': Decimal('152'),
#   'population': Decimal('45350148')},
#  {'country': 'Nigeria',
#   'total_cases': 267188,
#   'confirmed': 267188,
#   'new_cases': 0,
#   'deaths': 3155,
#   'new_deaths': 0,
#   'recovered': 259953,
#   'active': 4080,
#   'active_cases': 4080,
#   'critical': 11,
#   'total_tests': 5708974,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('1233'),
#   'total_deaths_per_million': Decimal('15'),
#   'population': Decimal('216746934')},
#  {'country': 'Zimbabwe',
#   'total_cases': 266359,
#   'confirmed': 266359,
#   'new_cases': 0,
#   'deaths': 5740,
#   'new_deaths': 0,
#   'recovered': 258888,
#   'active': 1731,
#   'active_cases': 1731,
#   'critical': 12,
#   'total_tests': 2525756,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('17373'),
#   'total_deaths_per_million': Decimal('374'),
#   'population': Decimal('15331428')},
#  {'country': 'Uzbekistan',
#   'total_cases': 253662,
#   'confirmed': 253662,
#   'new_cases': 0,
#   'deaths': 1637,
#   'new_deaths': 0,
#   'recovered': 241486,
#   'active': 10539,
#   'active_cases': 10539,
#   'critical': 23,
#   'total_tests': 1377915,
#   'total_tests_per_million': Decimal('0'),
# ...
#   'total_tests': 305941,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('15441'),
#   'total_deaths_per_million': Decimal('186'),
#   'population': Decimal('1016097')},
#  {'country': 'CAR',
#   'total_cases': 15440,
#   'confirmed': 15440,
#   'new_cases': 0,
#   'deaths': 113,
#   'new_deaths': 0,
#   'recovered': 15200,
#   'active': 127,
#   'active_cases': 127,
#   'critical': 2,
#   'total_tests': 81294,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('3078'),
#   'total_deaths_per_million': Decimal('23'),
#   'population': Decimal('5016678')},
#  {'country': 'Gambia',
#   'total_cases': 12626,
#   'confirmed': 12626,
#   'new_cases': 0,
#   'deaths': 372,
#   'new_deaths': 0,
#   'recovered': 12189,
#   'active': 65,
#   'active_cases': 65,
#   'critical': 0,
#   'total_tests': 155686,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('4935'),
#   'total_deaths_per_million': Decimal('145'),
#   'population': Decimal('2558482')},
#  {'country': 'Saint Martin',
#   'total_cases': 12324,
#   'confirmed': 12324,
#   'new_cases': 0,
#   'deaths': 63,
#   'new_deaths': 0,
#   'recovered': 0,
#   'active': 0,
#   'active_cases': 0,
#   'critical': 0,
#   'total_tests': 112382,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('310194'),
#   'total_deaths_per_million': Decimal('1586'),
#   'population': Decimal('39730')},
#  {'country': 'Vanuatu',
#   'total_cases': 12019,
#   'confirmed': 12019,
#   'new_cases': 0,
#   'deaths': 14,
#   'new_deaths': 0,
#   'recovered': 11976,
#   'active': 29,
#   'active_cases': 29,
#   'critical': 0,
#   'total_tests': 24976,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('37346'),
#   'total_deaths_per_million': Decimal('44'),
#   'population': Decimal('321832')},
#  {'country': 'Greenland',
#   'total_cases': 11971,
#   'confirmed': 11971,
#   'new_cases': 0,
#   'deaths': 21,
#   'new_deaths': 0,
#   'recovered': 2761,
#   'active': 9189,
#   'active_cases': 9189,
#   'critical': 4,
#   'total_tests': 164926,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('210117'),
#   'total_deaths_per_million': Decimal('369'),
#   'population': Decimal('56973')},
#  {'country': 'Yemen',
#   'total_cases': 11945,
#   'confirmed': 11945,
#   'new_cases': 0,
#   'deaths': 2159,
#   'new_deaths': 0,
#   'recovered': 9124,
#   'active': 662,
#   'active_cases': 662,
#   'critical': 0,
#   'total_tests': 329592,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('383'),
#   'total_deaths_per_million': Decimal('69'),
#   'population': Decimal('31154867')},
#  {'country': 'Caribbean Netherlands',
#   'total_cases': 11682,
#   'confirmed': 11682,
#   'new_cases': 0,
#   'deaths': 38,
#   'new_deaths': 0,
#   'recovered': 10476,
#   'active': 1168,
#   'active_cases': 1168,
#   'critical': 0,
#   'total_tests': 30126,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('438398'),
#   'total_deaths_per_million': Decimal('1426'),
#   'population': Decimal('26647')},
#  {'country': 'Sint Maarten',
#   'total_cases': 11051,
#   'confirmed': 11051,
#   'new_cases': 0,
#   'deaths': 92,
#   'new_deaths': 0,
#   'recovered': 10905,
#   'active': 54,
#   'active_cases': 54,
#   'critical': 0,
#   'total_tests': 62056,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('251353'),
#   'total_deaths_per_million': Decimal('2093'),
#   'population': Decimal('43966')},
#  {'country': 'Eritrea',
#   'total_cases': 10189,
#   'confirmed': 10189,
#   'new_cases': 0,
#   'deaths': 103,
#   'new_deaths': 0,
#   'recovered': 10086,
#   'active': 0,
#   'active_cases': 0,
#   'critical': 0,
#   'total_tests': 23693,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('2782'),
#   'total_deaths_per_million': Decimal('28'),
#   'population': Decimal('3662244')},
#  {'country': 'Niger',
#   'total_cases': 9931,
#   'confirmed': 9931,
#   'new_cases': 0,
#   'deaths': 312,
#   'new_deaths': 0,
#   'recovered': 8890,
#   'active': 729,
#   'active_cases': 729,
#   'critical': 1,
#   'total_tests': 254538,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('381'),
#   'total_deaths_per_million': Decimal('12'),
#   'population': Decimal('26083660')},
#  {'country': 'St. Vincent Grenadines',
#   'total_cases': 9674,
#   'confirmed': 9674,
#   'new_cases': 0,
#   'deaths': 124,
#   'new_deaths': 0,
#   'recovered': 9493,
#   'active': 57,
#   'active_cases': 57,
#   'critical': 0,
#   'total_tests': 114197,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('86723'),
#   'total_deaths_per_million': Decimal('1112'),
#   'population': Decimal('111551')},
#  {'country': 'Guinea-Bissau',
#   'total_cases': 9614,
#   'confirmed': 9614,
#   'new_cases': 0,
#   'deaths': 177,
#   'new_deaths': 0,
#   'recovered': 8929,
#   'active': 508,
#   'active_cases': 508,
#   'critical': 6,
#   'total_tests': 145231,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('4659'),
#   'total_deaths_per_million': Decimal('86'),
#   'population': Decimal('2063367')},
#  {'country': 'Comoros',
#   'total_cases': 9109,
#   'confirmed': 9109,
#   'new_cases': 0,
#   'deaths': 161,
#   'new_deaths': 0,
#   'recovered': 8939,
#   'active': 9,
#   'active_cases': 9,
#   'critical': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('10038'),
#   'total_deaths_per_million': Decimal('177'),
#   'population': Decimal('907419')},
#  {'country': 'Antigua and Barbuda',
#   'total_cases': 9106,
#   'confirmed': 9106,
#   'new_cases': 0,
#   'deaths': 146,
#   'new_deaths': 0,
#   'recovered': 8954,
#   'active': 6,
#   'active_cases': 6,
#   'critical': 0,
#   'total_tests': 18901,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('91509'),
#   'total_deaths_per_million': Decimal('1467'),
#   'population': Decimal('99509')},
#  {'country': 'Liberia',
#   'total_cases': 8090,
#   'confirmed': 8090,
#   'new_cases': 0,
#   'deaths': 295,
#   'new_deaths': 0,
#   'recovered': 7783,
#   'active': 12,
#   'active_cases': 12,
#   'critical': 2,
#   'total_tests': 139824,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('1525'),
#   'total_deaths_per_million': Decimal('56'),
#   'population': Decimal('5305117')},
#  {'country': 'Sierra Leone',
#   'total_cases': 7779,
#   'confirmed': 7779,
#   'new_cases': 0,
#   'deaths': 126,
#   'new_deaths': 0,
#   'recovered': 0,
#   'active': 0,
#   'active_cases': 0,
#   'critical': 0,
#   'total_tests': 259958,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('937'),
#   'total_deaths_per_million': Decimal('15'),
#   'population': Decimal('8306436')},
#  {'country': 'Chad',
#   'total_cases': 7701,
#   'confirmed': 7701,
#   'new_cases': 0,
#   'deaths': 194,
#   'new_deaths': 0,
#   'recovered': 4874,
#   'active': 2633,
#   'active_cases': 2633,
#   'critical': 0,
#   'total_tests': 191341,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('442'),
#   'total_deaths_per_million': Decimal('11'),
#   'population': Decimal('17413580')},
#  {'country': 'British Virgin Islands',
#   'total_cases': 7392,
#   'confirmed': 7392,
#   'new_cases': 0,
#   'deaths': 64,
#   'new_deaths': 0,
#   'recovered': 0,
#   'active': 0,
#   'active_cases': 0,
#   'critical': 0,
#   'total_tests': 107339,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('241600'),
#   'total_deaths_per_million': Decimal('2092'),
#   'population': Decimal('30596')},
#  {'country': 'Cook Islands',
#   'total_cases': 7203,
#   'confirmed': 7203,
#   'new_cases': 0,
#   'deaths': 2,
#   'new_deaths': 0,
#   'recovered': 7150,
#   'active': 51,
#   'active_cases': 51,
#   'critical': 0,
#   'total_tests': 19690,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('409937'),
#   'total_deaths_per_million': Decimal('114'),
#   'population': Decimal('17571')},
#  {'country': 'Sao Tome and Principe',
#   'total_cases': 6778,
#   'confirmed': 6778,
#   'new_cases': 0,
#   'deaths': 80,
#   'new_deaths': 0,
#   'recovered': 6685,
#   'active': 13,
#   'active_cases': 13,
#   'critical': 0,
#   'total_tests': 29600,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('29770'),
#   'total_deaths_per_million': Decimal('351'),
#   'population': Decimal('227679')},
#  {'country': 'Turks and Caicos',
#   'total_cases': 6752,
#   'confirmed': 6752,
#   'new_cases': 0,
#   'deaths': 40,
#   'new_deaths': 0,
#   'recovered': 6709,
#   'active': 3,
#   'active_cases': 3,
#   'critical': 4,
#   'total_tests': 616788,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('169900'),
#   'total_deaths_per_million': Decimal('1007'),
#   'population': Decimal('39741')},
#  {'country': 'Saint Kitts and Nevis',
#   'total_cases': 6607,
#   'confirmed': 6607,
#   'new_cases': 0,
#   'deaths': 48,
#   'new_deaths': 0,
#   'recovered': 6559,
#   'active': 0,
#   'active_cases': 0,
#   'critical': 0,
#   'total_tests': 126958,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('122645'),
#   'total_deaths_per_million': Decimal('891'),
#   'population': Decimal('53871')},
#  {'country': 'Palau',
#   'total_cases': 6290,
#   'confirmed': 6290,
#   'new_cases': 0,
#   'deaths': 10,
#   'new_deaths': 0,
#   'recovered': 6276,
#   'active': 4,
#   'active_cases': 4,
#   'critical': 0,
#   'total_tests': 71434,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('344979'),
#   'total_deaths_per_million': Decimal('548'),
#   'population': Decimal('18233')},
#  {'country': 'St. Barth',
#   'total_cases': 5507,
#   'confirmed': 5507,
#   'new_cases': 0,
#   'deaths': 6,
#   'new_deaths': 0,
#   'recovered': 0,
#   'active': 0,
#   'active_cases': 0,
#   'critical': 0,
#   'total_tests': 78646,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('553746'),
#   'total_deaths_per_million': Decimal('603'),
#   'population': Decimal('9945')},
#  {'country': 'Nauru',
#   'total_cases': 5393,
#   'confirmed': 5393,
#   'new_cases': 0,
#   'deaths': 1,
#   'new_deaths': 0,
#   'recovered': 5347,
#   'active': 45,
#   'active_cases': 45,
#   'critical': 0,
#   'total_tests': 20509,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('494635'),
#   'total_deaths_per_million': Decimal('92'),
#   'population': Decimal('10903')},
#  {'country': 'Kiribati',
#   'total_cases': 5085,
#   'confirmed': 5085,
#   'new_cases': 0,
#   'deaths': 24,
#   'new_deaths': 0,
#   'recovered': 2703,
#   'active': 2358,
#   'active_cases': 2358,
#   'critical': 3,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('41201'),
#   'total_deaths_per_million': Decimal('194'),
#   'population': Decimal('123419')},
#  {'country': 'Anguilla',
#   'total_cases': 3904,
#   'confirmed': 3904,
#   'new_cases': 0,
#   'deaths': 12,
#   'new_deaths': 0,
#   'recovered': 0,
#   'active': 0,
#   'active_cases': 0,
#   'critical': 0,
#   'total_tests': 51382,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('256336'),
#   'total_deaths_per_million': Decimal('788'),
#   'population': Decimal('15230')},
#  {'country': 'Wallis and Futuna',
#   'total_cases': 3550,
#   'confirmed': 3550,
#   'new_cases': 0,
#   'deaths': 8,
#   'new_deaths': 0,
#   'recovered': 438,
#   'active': 3104,
#   'active_cases': 3104,
#   'critical': 0,
#   'total_tests': 20508,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('323256'),
#   'total_deaths_per_million': Decimal('728'),
#   'population': Decimal('10982')},
#  {'country': 'Saint Pierre Miquelon',
#   'total_cases': 3452,
#   'confirmed': 3452,
#   'new_cases': 0,
#   'deaths': 2,
#   'new_deaths': 0,
#   'recovered': 2449,
#   'active': 1001,
#   'active_cases': 1001,
#   'critical': 0,
#   'total_tests': 25400,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('599410'),
#   'total_deaths_per_million': Decimal('347'),
#   'population': Decimal('5759')},
#  {'country': 'Tuvalu',
#   'total_cases': 2943,
#   'confirmed': 2943,
#   'new_cases': 0,
#   'deaths': 1,
#   'new_deaths': 0,
#   'recovered': 0,
#   'active': 0,
#   'active_cases': 0,
#   'critical': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('243909'),
#   'total_deaths_per_million': Decimal('83'),
#   'population': Decimal('12066')},
#  {'country': 'Saint Helena',
#   'total_cases': 2166,
#   'confirmed': 2166,
#   'new_cases': 0,
#   'deaths': 0,
#   'new_deaths': 0,
#   'recovered': 2,
#   'active': 2164,
#   'active_cases': 2164,
#   'critical': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('354211'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('6115')},
#  {'country': 'Falkland Islands',
#   'total_cases': 1930,
#   'confirmed': 1930,
#   'new_cases': 0,
#   'deaths': 0,
#   'new_deaths': 0,
#   'recovered': 1930,
#   'active': 0,
#   'active_cases': 0,
#   'critical': 0,
#   'total_tests': 8632,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('545352'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('3539')},
#  {'country': 'Montserrat',
#   'total_cases': 1403,
#   'confirmed': 1403,
#   'new_cases': 0,
#   'deaths': 8,
#   'new_deaths': 0,
#   'recovered': 1376,
#   'active': 19,
#   'active_cases': 19,
#   'critical': 0,
#   'total_tests': 17762,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('282578'),
#   'total_deaths_per_million': Decimal('1611'),
#   'population': Decimal('4965')},
#  {'country': 'Niue',
#   'total_cases': 1059,
#   'confirmed': 1059,
#   'new_cases': 0,
#   'deaths': 0,
#   'new_deaths': 0,
#   'recovered': 1056,
#   'active': 3,
#   'active_cases': 3,
#   'critical': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('652898'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('1622')},
#  {'country': 'Diamond Princess',
#   'total_cases': 712,
#   'confirmed': 712,
#   'new_cases': 0,
#   'deaths': 13,
#   'new_deaths': 0,
#   'recovered': 699,
#   'active': 0,
#   'active_cases': 0,
#   'critical': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('0'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('0')},
#  {'country': 'Tokelau',
#   'total_cases': 80,
#   'confirmed': 80,
#   'new_cases': 0,
#   'deaths': 0,
#   'new_deaths': 0,
#   'recovered': 0,
#   'active': 80,
#   'active_cases': 80,
#   'critical': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('58055'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('1378')},
#  {'country': 'Vatican City',
#   'total_cases': 29,
#   'confirmed': 29,
#   'new_cases': 0,
#   'deaths': 0,
#   'new_deaths': 0,
#   'recovered': 29,
#   'active': 0,
#   'active_cases': 0,
#   'critical': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('36295'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('799')},
#  {'country': 'Western Sahara',
#   'total_cases': 10,
#   'confirmed': 10,
#   'new_cases': 0,
#   'deaths': 1,
#   'new_deaths': 0,
#   'recovered': 9,
#   'active': 0,
#   'active_cases': 0,
#   'critical': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('16'),
#   'total_deaths_per_million': Decimal('2'),
#   'population': Decimal('626161')},
#  {'country': 'MS Zaandam',
#   'total_cases': 9,
#   'confirmed': 9,
#   'new_cases': 0,
#   'deaths': 2,
#   'new_deaths': 0,
#   'recovered': 7,
#   'active': 0,
#   'active_cases': 0,
#   'critical': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('0'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('0')},
#  {'country': 'China',
#   'total_cases': 503302,
#   'confirmed': 503302,
#   'new_cases': 0,
#   'deaths': 5272,
#   'new_deaths': 0,
#   'recovered': 379053,
#   'active': 118977,
#   'active_cases': 118977,
#   'critical': 0,
#   'total_tests': 160000000,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('347'),
#   'total_deaths_per_million': Decimal('4'),
#   'population': Decimal('1448471400')}]

# %%
covid.source
# Out:
# 'worldometers'

# %%
covid.get_status_by_country_name("italy")
# Out:
# {'country': 'Italy',
#  'total_cases': 26723249,
#  'confirmed': 26723249,
#  'new_cases': 0,
#  'deaths': 196487,
#  'new_deaths': 0,
#  'recovered': 26361218,
#  'active': 165544,
#  'active_cases': 165544,
#  'critical': 22,
#  'total_tests': 281126449,
#  'total_tests_per_million': Decimal('0'),
#  'total_cases_per_million': Decimal('443445'),
#  'total_deaths_per_million': Decimal('3261'),
#  'population': Decimal('60262770')}

# %%
covid.list_countries()
# Out:
# ['north america',
#  'asia',
#  'europe',
#  'south america',
#  'oceania',
#  'africa',
#  '',
#  'world',
#  'usa',
#  'india',
#  'france',
#  'germany',
#  'brazil',
#  's. korea',
#  'japan',
#  'italy',
#  'uk',
#  'russia',
#  'turkey',
#  'spain',
#  'australia',
#  'vietnam',
#  'taiwan',
#  'argentina',
#  'netherlands',
#  'mexico',
#  'iran',
#  'indonesia',
#  'poland',
#  'colombia',
#  'greece',
#  'austria',
#  'portugal',
#  'ukraine',
#  'chile',
#  'malaysia',
#  'canada',
#  'belgium',
#  'israel',
#  'dprk',
#  'thailand',
#  'czechia',
#  'peru',
#  'switzerland',
#  'philippines',
#  'south africa',
#  'romania',
#  'denmark',
#  'singapore',
#  'hong kong',
#  'sweden',
#  'new zealand',
#  'serbia',
#  'iraq',
#  'hungary',
#  'bangladesh',
#  'slovakia',
#  'georgia',
#  'jordan',
#  'ireland',
#  'pakistan',
#  'finland',
#  'norway',
#  'kazakhstan',
#  'lithuania',
#  'slovenia',
#  'bulgaria',
#  'croatia',
#  'guatemala',
#  'morocco',
#  'lebanon',
#  'costa rica',
#  'bolivia',
#  'tunisia',
#  'cuba',
#  'ecuador',
#  'uae',
#  'panama',
#  'uruguay',
#  'mongolia',
#  'nepal',
#  'belarus',
#  'latvia',
#  'saudi arabia',
#  'paraguay',
#  'azerbaijan',
#  'bahrain',
#  'cyprus',
#  'dominican republic',
#  'sri lanka',
#  'kuwait',
#  'myanmar',
#  'moldova',
#  'estonia',
#  'palestine',
#  'venezuela',
#  'egypt',
#  'qatar',
#  'libya',
#  'ethiopia',
#  'réunion',
#  'honduras',
#  'armenia',
#  'bosnia and herzegovina',
#  'oman',
#  'luxembourg',
#  'north macedonia',
#  'zambia',
#  'kenya',
#  'brunei',
#  'albania',
#  'botswana',
#  'montenegro',
#  'algeria',
#  'nigeria',
#  'zimbabwe',
#  'uzbekistan',
#  'afghanistan',
#  'mozambique',
#  'martinique',
#  'laos',
#  'iceland',
#  'kyrgyzstan',
#  'guadeloupe',
#  'el salvador',
#  'trinidad and tobago',
#  'maldives',
#  'namibia',
#  'uganda',
#  'ghana',
#  'jamaica',
#  'cambodia',
#  'rwanda',
#  'cameroon',
#  'malta',
#  'barbados',
#  'angola',
#  'channel islands',
#  'drc',
#  'french guiana',
#  'malawi',
#  'senegal',
#  'ivory coast',
#  'suriname',
#  'new caledonia',
#  'french polynesia',
#  'eswatini',
#  'guyana',
#  'belize',
#  'fiji',
#  'madagascar',
#  'cabo verde',
#  'sudan',
#  'mauritania',
#  'bhutan',
#  'syria',
#  'burundi',
#  'seychelles',
#  'gabon',
#  'andorra',
#  'papua new guinea',
#  'curaçao',
#  'aruba',
#  'tanzania',
#  'mauritius',
#  'mayotte',
#  'togo',
#  'guinea',
#  'bahamas',
#  'isle of man',
#  'lesotho',
#  'haiti',
#  'faeroe islands',
#  'mali',
#  'cayman islands',
#  'saint lucia',
#  'benin',
#  'macao',
#  'somalia',
#  'micronesia',
#  'san marino',
#  'solomon islands',
#  'congo',
#  'timor-leste',
#  'burkina faso',
#  'liechtenstein',
#  'gibraltar',
#  'grenada',
#  'bermuda',
#  'south sudan',
#  'nicaragua',
#  'tajikistan',
#  'equatorial guinea',
#  'monaco',
#  'samoa',
#  'tonga',
#  'marshall islands',
#  'dominica',
#  'djibouti',
#  'car',
#  'gambia',
#  'saint martin',
#  'vanuatu',
#  'greenland',
#  'yemen',
#  'caribbean netherlands',
#  'sint maarten',
#  'eritrea',
#  'niger',
#  'st. vincent grenadines',
#  'guinea-bissau',
#  'comoros',
#  'antigua and barbuda',
#  'liberia',
#  'sierra leone',
#  'chad',
#  'british virgin islands',
#  'cook islands',
#  'sao tome and principe',
#  'turks and caicos',
#  'saint kitts and nevis',
#  'palau',
#  'st. barth',
#  'nauru',
#  'kiribati',
#  'anguilla',
#  'wallis and futuna',
#  'saint pierre miquelon',
#  'tuvalu',
#  'saint helena',
#  'falkland islands',
#  'montserrat',
#  'niue',
#  'diamond princess',
#  'tokelau',
#  'vatican city',
#  'western sahara',
#  'ms zaandam',
#  'china']

# %%
covid.get_total_active_cases()
# Out:
# 22123398

# %%
covid.get_total_confirmed_cases()
# Out:
# 704753890

# %%
covid.get_total_deaths()
# Out:
# 7010681

# %%
import pandas as pd

# %%
df = pd.DataFrame(covid.get_data())
print(df)
# Out:
#             country  total_cases  confirmed  new_cases   deaths  new_deaths  \
# 0     North America    131889132  131889132          0  1695941           0
# 1              Asia    221500265  221500265          0  1553662           0
# 2            Europe    253406198  253406198          0  2101824           0
# 3     South America     70200879   70200879          0  1367332           0
# 4           Oceania     14895771   14895771          0    33015           0
# ..              ...          ...        ...        ...      ...         ...
# 234         Tokelau           80         80          0        0           0
# 235    Vatican City           29         29          0        0           0
# 236  Western Sahara           10         10          0        1           0
# 237      MS Zaandam            9          9          0        2           0
# 238           China       503302     503302          0     5272           0
#
#      recovered    active  active_cases  critical  total_tests  \
# 0    127665129   2528062       2528062      6095            0
# 1    205673091  14273512      14273512     14733            0
# 2    248754104   2550270       2550270      4453            0
# 3     66683585   2149962       2149962      8953            0
# 4     14752388    110368        110368        31            0
# ..         ...       ...           ...       ...          ...
# 234          0        80            80         0            0
# 235         29         0             0         0            0
# 236          9         0             0         0            0
# 237          7         0             0         0            0
# 238     379053    118977        118977         0    160000000
#
#     total_tests_per_million total_cases_per_million total_deaths_per_million  \
# 0                         0                       0                        0
# 1                         0                       0                        0
# 2                         0                       0                        0
# 3                         0                       0                        0
# 4                         0                       0                        0
# ..                      ...                     ...                      ...
# 234                       0                   58055                        0
# 235                       0                   36295                        0
# 236                       0                      16                        2
# 237                       0                       0                        0
# 238                       0                     347                        4
#
#      population
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0
# ..          ...
# 234        1378
# 235         799
# 236      626161
# 237           0
# 238  1448471400
#
# [239 rows x 15 columns]

# %%
sorted = df.sort_values(by = ['confirmed'], ascending = False)

# %%
excluded = sorted[~sorted['country'].isin(['Europe', 'South America', 'Asia', 'World', 'North America'])]
top10 = excluded.head(10)
print(top10)
# Out:
#      country  total_cases  confirmed  new_cases   deaths  new_deaths  \
# 8        USA    111820082  111820082          0  1219487           0
# 9      India     45035393   45035393          0   533570           0
# 10    France     40138560   40138560          0   167642           0
# 11   Germany     38828995   38828995          0   183027           0
# 12    Brazil     38743918   38743918          0   711380           0
# 13  S. Korea     34571873   34571873          0    35934           0
# 14     Japan     33803572   33803572          0    74694           0
# 15     Italy     26723249   26723249          0   196487           0
# 16        UK     24910387   24910387          0   232112           0
# 17    Russia     24124215   24124215          0   402756           0
#
#     recovered   active  active_cases  critical  total_tests  \
# 8   109814428   786167        786167       940   1186851502
# 9           0        0             0         0    935879495
# 10   39970918        0             0         0    271490188
# 11   38240600   405368        405368         0    122332384
# 12   36249161  1783377       1783377         0     63776166
# 13   34535939        0             0         0     15804065
# 14          0        0             0         0    100414883
# 15   26361218   165544        165544        22    281126449
# 16   24678275        0             0         0    522526476
# 17   23545818   175641        175641         0    273400000
#
#    total_tests_per_million total_cases_per_million total_deaths_per_million  \
# 8                        0                  333985                     3642
# 9                        0                   32016                      379
# 10                       0                  612013                     2556
# 11                       0                  462891                     2182
# 12                       0                  179908                     3303
# 13                       0                  673523                      700
# 14                       0                  269169                      595
# 15                       0                  443445                     3261
# 16                       0                  363666                     3389
# 17                       0                  165454                     2762
#
#     population
# 8    334805269
# 9   1406631776
# 10    65584518
# 11    83883596
# 12   215353593
# 13    51329899
# 14   125584838
# 15    60262770
# 16    68497907
# 17   145805947

# %%
top10 = excluded.head(10)
print(top10)
# Out:
#      country  total_cases  confirmed  new_cases   deaths  new_deaths  \
# 8        USA    111820082  111820082          0  1219487           0
# 9      India     45035393   45035393          0   533570           0
# 10    France     40138560   40138560          0   167642           0
# 11   Germany     38828995   38828995          0   183027           0
# 12    Brazil     38743918   38743918          0   711380           0
# 13  S. Korea     34571873   34571873          0    35934           0
# 14     Japan     33803572   33803572          0    74694           0
# 15     Italy     26723249   26723249          0   196487           0
# 16        UK     24910387   24910387          0   232112           0
# 17    Russia     24124215   24124215          0   402756           0
#
#     recovered   active  active_cases  critical  total_tests  \
# 8   109814428   786167        786167       940   1186851502
# 9           0        0             0         0    935879495
# 10   39970918        0             0         0    271490188
# 11   38240600   405368        405368         0    122332384
# 12   36249161  1783377       1783377         0     63776166
# 13   34535939        0             0         0     15804065
# 14          0        0             0         0    100414883
# 15   26361218   165544        165544        22    281126449
# 16   24678275        0             0         0    522526476
# 17   23545818   175641        175641         0    273400000
#
#    total_tests_per_million total_cases_per_million total_deaths_per_million  \
# 8                        0                  333985                     3642
# 9                        0                   32016                      379
# 10                       0                  612013                     2556
# 11                       0                  462891                     2182
# 12                       0                  179908                     3303
# 13                       0                  673523                      700
# 14                       0                  269169                      595
# 15                       0                  443445                     3261
# 16                       0                  363666                     3389
# 17                       0                  165454                     2762
#
#     population
# 8    334805269
# 9   1406631776
# 10    65584518
# 11    83883596
# 12   215353593
# 13    51329899
# 14   125584838
# 15    60262770
# 16    68497907
# 17   145805947

# %%
x = top10.country
y1 = top10.confirmed
y2 = top10.active
y3 = top10.deaths
y4 = top10.recovered

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(x, y1)
plt.xticks(rotation=90)
plt.show()

# %%
plt.bar(x, y1)
plt.xticks(rotation=90)
plt.show()

# %%
plt.plot(x, y1, label = 'Confirmed')
plt.plot(x, y2, label = 'Active')
plt.plot(x, y3, label = 'Deaths')
plt.plot(x, y4, label = 'Recovered')
plt.legend(loc='upper right')
plt.xticks(rotation=90)
plt.show()

# %%
labels = ['Confirmed', 'Active', 'Deaths', 'Recovered']
plt.plot(x, y1, x, y2, x, y3, x, y4)
plt.legend(labels, loc='upper right')
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %%
df2 = pd.DataFrame([y1, y2, y3, y4])
df2.plot.bar()
plt.legend(x, loc = 'upper center')
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %%
df2.plot.bar(stacked = True);
plt.legend(x, loc = 'upper center')
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %%
df2.plot.barh()
plt.legend(x, loc = 'upper center')
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %%
df2.plot.barh(stacked = True);
plt.legend(x, loc = 'upper right')
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %%
df2.plot.area();
plt.legend(x, loc = 'upper right')
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %%
df2.plot.area(stacked = False);
plt.legend(x, loc = 'upper right')
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %%
factor = 0.0001
plt.scatter(x, y1, s=y1*factor);
plt.scatter(x, y2, s=y2*factor);
plt.scatter(x, y3, s=y3*factor);
plt.scatter(x, y4, s=y4*factor);
plt.legend(labels, loc='upper right')
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %%
plt.pie(y1, labels=x)
plt.title('Confirmed Cases')
plt.show()
